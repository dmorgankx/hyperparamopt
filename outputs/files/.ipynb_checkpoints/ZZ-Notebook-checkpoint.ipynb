# %% [markdown]
# ## Analyzing results from hyperopt

# %% [markdown]
# ### Read in results
#
# Utility functions.

# %%
// read results dictionary from txt files
get_data:{[x]
 fnc:{key(!).("S=,")0:x};$[1<count first x;fnc each;fnc]x}

// get names of model used and dataset
get_mdl_dset:{2#"_"vs ssr[y;x;x,"_"]}

// convert results to correct datatypes in table
load_hpopt_res:{[ptyp;fp;fn]
 prms:`$get_mdl_dset[$[ptyp~`class;"Classifier";"Regressor"]]fn;
 d:get_data each@[d;;";"vs]c:where";"in/:d:(!).("S*";"|")0:hsym`$fp,fn;
 d:{@[x;y;$[z;]string@]}/[d;`fold_score`random_state`time`score;"FITF"];
 d:flip raze each@[d;cols[d]except`fold_score;{count[first x`fold_score]#y}[d]each];
 select mdl:prms 0,dataset:prms 1,method,fold_score,score,time from d}

# %% [markdown]
# Read in all files and separate into class/reg.

# %%
files@:where(files:system"ls")like"*.txt"
show files:`class`reg!files(where;where not::)@\:files like"*Classifier*"
# Out:
# class| ("AdaBoostClassifierbreastcancer_2020.06.29_16.25.36.690.txt";"AdaBoos..
# reg  | ("GradientBoostingRegressorfish_2020.07.01_13.03.57.060.txt";"Gradient..

# %% [markdown]
# Get model and dataset names from filenames.

# %%
class_prms:get_mdl_dset["Classifier"]each files`class
show reg_prms:`$get_mdl_dset["Regressor"]each files`reg
# Out:
# GradientBoostingRegressor fish
# GradientBoostingRegressor hr
# GradientBoostingRegressor insurance
# RandomForestRegressor     fish
# RandomForestRegressor     hr
# RandomForestRegressor     insurance

# %% [markdown]
# Read in class and reg results, select relevant cols and separate fold score.

# %%
class:raze load_hpopt_res[`class;"./"]each files`class
5#reg:raze load_hpopt_res[`reg;"./"]each files`reg
# Out:
# mdl                       dataset method fold_score score    time
# -------------------------------------------------------------------------
# GradientBoostingRegressor fish    grid   0.9802354  0.982098 00:01:07.004
# GradientBoostingRegressor fish    grid   0.9641517  0.982098 00:01:07.004
# GradientBoostingRegressor fish    grid   0.9693964  0.982098 00:01:07.004
# GradientBoostingRegressor fish    grid   0.9749575  0.982098 00:01:07.004
# GradientBoostingRegressor fish    grid   0.9654277  0.982098 00:01:07.004

# %% [markdown]
# ### Preprocess results for plotting

# %%
// python imports
plt:.p.import`matplotlib.pyplot

// prep data for plotting - returning xticks/labels, scores and dataset index
prep_for_plot:{[c2plt;t;typ]
  // distinct methods for xticks
  mtd:(xtick:distinct t`method)!til 4;
  t:update nm:mtd method from t;
  // group data for plotting (dataset;method 0-3;scores)
  (xtick;{[c;t;d]d,value?[t;enlist(=;`dataset;enlist d);();k!k:`nm,c]}[c2plt;t]each dd:distinct t`dataset)}

# %% [markdown]
# ### Generate stats for plotting

# %%
// plot each model's results as a subplot
plot_res:{[c;typ;r]
  fig:plt[`:figure][`figsize pykw 12 12];
  ax1:fig[`:add_subplot][221];
  ax2:fig[`:add_subplot][222;`sharex pykw ax1;`sharey pykw ax1];
  ax3:fig[`:add_subplot][223;`sharex pykw ax1;`sharey pykw ax1];
  ax4:fig[`:add_subplot][224;`sharex pykw ax1;`sharey pykw ax1];
  ttl:$[b:typ=`stats;"Average ",c," of hyperopt methods";c," comparison for hyperopt methods"];
  {[typ;ttl;c;a;r]
    subplot_res[typ;ttl;c;a;r 0]each r 1;
    }[b;ttl;c]'[(ax1;ax2;ax3;ax4);r];
  plt[`:show][];}

// plot statistics or results
subplot_res:{[typ;ttl;c;a;tick;t]
 $[typ;
  a[`:bar][til 4;t[;0];`yerr pykw t[;1];`align pykw`center;`alpha pykw .5;`ecolor pykw`black;`capsize pykw 10];
  a[`:scatter][t 1;t 2;`label pykw t 0]];
 a[`:set_xticks]til 4; 
 a[`:set_xticklabels]tick;
 a[`:set_title]ttl;
 a[`:set_xlabel]`Method;
 a[`:set_ylabel]c;
 $[typ;a[`:yaxis.grid]1b;a[`:legend][]];}

# %% [markdown]
# Separate by model.

# %%
show mdlres:{[x;y]select from x where mdl=y}[class]each m:distinct class`mdl
# Out:
# +`mdl`dataset`method`fold_score`score`time!(`AdaBoostClassifier`AdaBoostClass..
# +`mdl`dataset`method`fold_score`score`time!(`GradientBoostingClassifier`Gradi..
# +`mdl`dataset`method`fold_score`score`time!(`RandomForestClassifier`RandomFor..
# +`mdl`dataset`method`fold_score`score`time!(`SGDClassifier`SGDClassifier`SGDC..

# %% [markdown]
# ### Fold score results

# %%
plot_res["Fold score";`res]prep_for_plot'[`fold_score;mdlres;m]

# %% [markdown]
# ### Testing score results

# %%
plot_res["Best Average Score";`res]prep_for_plot'[`score;mdlres;m]

# %% [markdown]
# ### Time comparison

# %%
plot_res["Time";`res]prep_for_plot'[`time;mdlres;m]

# %% [markdown]
# ### Fold score stats

# %%
get_stats:{
  x:raze{flip@[x;;{5#x}]cols[x]except`fold_score}each x;
  (d;enlist{[x;y](avg;dev)@\:exec fold_score from x where method=y}[x]each d:distinct x`method)}

# %%
mdlres_stats:{[x]select from x where dataset<>`iris}each mdlres

# %%
plot_res["fold score";`stats]gs:get_stats each mdlres_stats

# %%
show stats:raze{[x;y]update method:x 0,model:y from flip`mean`stddev!flip raze x 1}'[gs;til 4]
# Out:
# mean      stddev     method   model
# -----------------------------------
# 0.9126841 0.04926611 grid     0
# 0.8676048 0.04600308 random   0
# 0.8846871 0.04846356 sobol    0
# 0.9060196 0.0498778  bayesian 0
# 0.9063246 0.05169236 grid     1
# 0.8825235 0.04214398 random   1
# 0.8894209 0.04347685 sobol    1
# 0.9078383 0.04711878 bayesian 1
# 0.908681  0.05158146 grid     2
# 0.8664597 0.04441503 random   2
# 0.8671923 0.04506621 sobol    2
# 0.9069238 0.04504705 bayesian 2
# 0.8826256 0.04217882 grid     3
# 0.8893988 0.04756773 random   3
# 0.8895677 0.0472331  sobol    3
# 0.8720069 0.05077107 bayesian 3

# %% [markdown]
# ---
